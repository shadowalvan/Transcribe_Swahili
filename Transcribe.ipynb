# %% [markdown]
# <a href="https://colab.research.google.com/github/shadowalvan/Transcribe_Swahili/blob/main/Transcribe.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install git+https://github.com/openai/whisper.git
# !sudo apt update && sudo apt install ffmpeg
# Out:
# ...
#   Cloning https://github.com/openai/whisper.git to /tmp/pip-req-build-_wgxbzz9
#   Running command git clone --filter=blob:none --quiet https://github.com/openai/whisper.git /tmp/pip-req-build-_wgxbzz9
#   Resolved https://github.com/openai/whisper.git to commit c0d2f624c09dc18e709e37c2ad90c039a4eb72a2
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for openai-whisper: filename=openai_whisper-20250625-py3-none-any.whl size=803979 sha256=c7f41ae4cb6947c0d8188db48fc2fcf818a0dbc8a7cbee2bdceae370c35768fe
#   Stored in directory: /tmp/pip-ephem-wheel-cache-d32ez1_l/wheels/c3/03/25/5e0ba78bc27a3a089f137c9f1d92fdfce16d06996c071a016c
# Successfully built openai-whisper
# ...
# Get:1 https://cli.github.com/packages stable InRelease [3,917 B]
# Get:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# ...

# %%
# !whisper "audio1.mp3" --model base
# Out:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/whisper/audio.py", line 58, in load_audio
#     out = run(cmd, capture_output=True, check=True).stdout
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/subprocess.py", line 571, in run
#     raise CalledProcessError(retcode, process.args,
# subprocess.CalledProcessError: Command '['ffmpeg', '-nostdin', '-threads', '0', '-i', 'audio1.mp3', '-f', 's16le', '-ac', '1', '-acodec', 'pcm_s16le', '-ar', '16000', '-']' returned non-zero exit status 1.
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/whisper/transcribe.py", line 615, in cli
#     result = transcribe(model, audio_path, temperature=temperature, **args)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ...

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-12d6e408-bb69-455e-a408-e77c197c4335" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-12d6e408-bb69-455e-a408-e77c197c4335">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !ls
# Out:
# 'proxy-audio (1) (1).mp3'   sample_data

# %%
# !whisper "proxy-audio (1) (1).mp3" --model base --language sw
# Out:
# [00:00.000 --> 00:03.200]  Kuatakui muzamwa kefumbirina eshirina inane
# [00:03.200 --> 00:07.520]  maambukizi yamaeria katikari mashawrietu ni asimia sasuna saba
# [00:07.520 --> 00:10.480]  ambani kuguwa ukiringa ni syana mai neomengine
# [00:10.480 --> 00:13.200]  o sisitupo ilu kiwango cadu kabisaincini
# [00:13.200 --> 00:15.480]  koiyo ogaadioanetutasaidia sana
# [00:15.480 --> 00:18.840]  pongozaza asimia sasuna saba natuna lenga kiasi furi
# [00:18.840 --> 00:23.400]  kuawirano ukiringa nana mai lekezoia wio ni kuamba
# [00:23.400 --> 00:27.920]  neti modia niwatu awili kuawirano huo koiyo kamakaya
# [00:27.920 --> 00:30.920]  niwatu ane wa tapata neti ni bili
# [00:30.920 --> 00:35.320]  niwku murengi ni anbalori ni tafwa tabada yoan dekisha ni manaake
# [00:35.320 --> 00:38.560]  ni kuleta ni tekuri nana mai kari lyo
# [00:38.560 --> 00:41.920]  ou watu alogi yan dekisha kupata izonet

# %%
# Use a larger multilingual model
# !whisper "proxy-audio (1) (1).mp3" --model medium --language sw --task transcribe
# Out:
# 100%|██████████████████████████████████████| 1.42G/1.42G [00:13<00:00, 115MiB/s]
# [00:00.000 --> 00:07.360]  Kwa takuimuza mwa kefumbili na ishirini na nne, maambukizi ya maleri ya katikali mashaulietu ni asimia sasina saba
# [00:07.360 --> 00:10.400]  Ambo ni kubwa ukilinganisha na maeneo mengine
# [00:10.400 --> 00:13.120]  O sisi tupo juu, kiwango cha juu kabisa inchini
# [00:13.120 --> 00:17.320]  Kwa iyo ugawajiwa netu tasaidia sana kupunguzazu asimia sasina saba
# [00:17.320 --> 00:26.600]  Na tunalenga kia sifuli kwa wiyano kuringana na maelekezo ya WHO ni kwa mba neti mojia ni watu wawili kwa wiyano huo
# [00:26.640 --> 00:30.840]  Kwa iyo kama kaya ina watu wane wata pata neti mbili
# [00:30.840 --> 00:35.360]  Juukumu lingine ambolo litafwata bada ya wandikisha juu imana hake
# [00:35.360 --> 00:41.760]  Ni kuleta neti kuringana na makadilio, awu watu waleoji ya wandikisha kupata izo neti
